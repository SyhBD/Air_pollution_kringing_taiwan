# %%
import pandas as pd
import numpy as np

# %%
district_code = pd.read_excel("../行政區中心點.xlsx")

# %%
district_code
# Out:
#        行政區名  _x0033_碼郵遞區號       中心點經度      中心點緯度  \
# 0    臺北市中正區           100  121.519884  25.032405
# 1    臺北市大同區           103  121.513042  25.063424
# 2    臺北市中山區           104  121.538160  25.069699
# 3    臺北市松山區           105  121.557588  25.059991
# 4    臺北市大安區           106  121.543445  25.026770
# ..      ...           ...         ...        ...
# 366  花蓮縣瑞穗鄉           978  121.407347  23.515612
# 367  花蓮縣萬榮鄉           979  121.318953  23.727726
# 368  花蓮縣玉里鎮           981  121.360448  23.371436
# 369  花蓮縣卓溪鄉           982  121.180422  23.390629
# 370  花蓮縣富里鄉           983  121.298049  23.196721
#
#                                               TGOS_URL
# 0    http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...
# 1    http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...
# 2    http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...
# 3    http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...
# 4    http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...
# ...

# %%
country = []
for i in range(0,371):
    country.append("臺灣")

# %%
len(country)
# Out:
# 371

# %%
city = []
for i in range(0,371):
    city.append(district_code.iloc[i,0][:3])

# %%
city
# Out:
# ['臺北市',
#  '臺北市',
#  '臺北市',
#  '臺北市',
#  '臺北市',
#  '臺北市',
#  '臺北市',
#  '臺北市',
#  '臺北市',
#  '臺北市',
#  '臺北市',
#  '臺北市',
#  '基隆市',
#  '基隆市',
#  '基隆市',
#  '基隆市',
#  '基隆市',
#  '基隆市',
#  '基隆市',
#  '新北市',
#  '新北市',
#  '連江縣',
#  '連江縣',
#  '連江縣',
#  '連江縣',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '新北市',
#  '宜蘭縣',
#  '宜蘭縣',
#  '宜蘭縣',
#  '宜蘭縣',
#  '宜蘭縣',
#  '宜蘭縣',
#  '宜蘭縣',
#  '宜蘭縣',
#  '宜蘭縣',
#  '宜蘭縣',
#  '宜蘭縣',
#  '宜蘭縣',
#  '宜蘭縣',
#  '新竹市',
#  '新竹市',
#  '新竹市',
#  '新竹縣',
#  '新竹縣',
#  '新竹縣',
#  '新竹縣',
#  '新竹縣',
#  '新竹縣',
#  '新竹縣',
#  '新竹縣',
#  '新竹縣',
#  '新竹縣',
#  '新竹縣',
#  '新竹縣',
#  '新竹縣',
#  '桃園市',
#  '桃園市',
#  '桃園市',
#  '桃園市',
#  '桃園市',
#  '桃園市',
#  '桃園市',
#  '桃園市',
#  '桃園市',
#  '桃園市',
#  '桃園市',
#  '桃園市',
#  '桃園市',
#  '苗栗縣',
#  '苗栗縣',
#  '苗栗縣',
#  '苗栗縣',
#  '苗栗縣',
#  '苗栗縣',
# ...

# %%
district = []
for i in range(0,371):
    district.append(district_code.iloc[i,0][3:])

# %%
district
# Out:
# ['中正區',
#  '大同區',
#  '中山區',
#  '松山區',
#  '大安區',
#  '萬華區',
#  '信義區',
#  '士林區',
#  '北投區',
#  '內湖區',
#  '南港區',
#  '文山區',
#  '仁愛區',
#  '信義區',
#  '中正區',
#  '中山區',
#  '安樂區',
#  '暖暖區',
#  '七堵區',
#  '萬里區',
#  '金山區',
#  '南竿鄉',
#  '北竿鄉',
#  '莒光鄉',
#  '東引鄉',
#  '板橋區',
#  '汐止區',
#  '深坑區',
#  '石碇區',
#  '瑞芳區',
#  '平溪區',
#  '雙溪區',
#  '貢寮區',
#  '新店區',
#  '坪林區',
#  '烏來區',
#  '永和區',
#  '中和區',
#  '土城區',
#  '三峽區',
#  '樹林區',
#  '鶯歌區',
#  '三重區',
#  '新莊區',
#  '泰山區',
#  '林口區',
#  '蘆洲區',
#  '五股區',
#  '八里區',
#  '淡水區',
#  '三芝區',
#  '石門區',
#  '宜蘭市',
#  '頭城鎮',
#  '礁溪鄉',
#  '壯圍鄉',
#  '員山鄉',
#  '羅東鎮',
#  '三星鄉',
#  '大同鄉',
#  '五結鄉',
#  '冬山鄉',
#  '蘇澳鎮',
#  '南澳鄉',
#  '釣魚臺列嶼',
#  '北區',
#  '東區',
#  '香山區',
#  '竹北市',
#  '湖口鄉',
#  '新豐鄉',
#  '新埔鎮',
#  '關西鎮',
#  '芎林鄉',
#  '寶山鄉',
#  '竹東鎮',
#  '五峰鄉',
#  '橫山鄉',
#  '尖石鄉',
#  '北埔鄉',
#  '峨眉鄉',
#  '中壢區',
#  '平鎮區',
#  '龍潭區',
#  '楊梅區',
#  '新屋區',
#  '觀音區',
#  '桃園區',
#  '龜山區',
#  '八德區',
#  '大溪區',
#  '復興區',
#  '大園區',
#  '蘆竹區',
#  '竹南鎮',
#  '頭份市',
#  '三灣鄉',
#  '南庄鄉',
#  '獅潭鄉',
#  '後龍鎮',
# ...

# %%
district_code_mod = district_code.copy()

# %%
district_code_mod["國家"] = country
district_code_mod["縣市"] = city
district_code_mod["城鄉鎮區"] = district

# %%
district_code_mod
# Out:
#        行政區名  _x0033_碼郵遞區號       中心點經度      中心點緯度  \
# 0    臺北市中正區           100  121.519884  25.032405
# 1    臺北市大同區           103  121.513042  25.063424
# 2    臺北市中山區           104  121.538160  25.069699
# 3    臺北市松山區           105  121.557588  25.059991
# 4    臺北市大安區           106  121.543445  25.026770
# ..      ...           ...         ...        ...
# 366  花蓮縣瑞穗鄉           978  121.407347  23.515612
# 367  花蓮縣萬榮鄉           979  121.318953  23.727726
# 368  花蓮縣玉里鎮           981  121.360448  23.371436
# 369  花蓮縣卓溪鄉           982  121.180422  23.390629
# 370  花蓮縣富里鄉           983  121.298049  23.196721
#
#                                               TGOS_URL  國家   縣市 城鄉鎮區
# 0    http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  臺灣  臺北市  中正區
# 1    http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  臺灣  臺北市  大同區
# 2    http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  臺灣  臺北市  中山區
# 3    http://tgos.nat.gov.tw/tgos/Web/MetaData/TGOS_...  臺灣  臺北市  松山區
# ...

# %%
district_code_mod.to_excel("../行政區中心點_mod.xlsx", index=None)
